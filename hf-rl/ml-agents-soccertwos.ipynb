# %%
! conda create --name rl python=3.9 -y
! conda activate rl
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 22.9.0
#   latest version: 23.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/rl
#
#   added / updated specs:
#     - python=3.9
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     _libgcc_mutex-0.1          |      conda_forge           3 KB  conda-forge
#     _openmp_mutex-4.5          |            2_gnu          23 KB  conda-forge
#     ld_impl_linux-64-2.40      |       h41732ed_0         688 KB  conda-forge
#     ncurses-6.3                |       h27087fc_1        1002 KB  conda-forge
#     openssl-3.1.0              |       h0b41bf4_0         2.5 MB  conda-forge
#     pip-23.0.1                 |     pyhd8ed1ab_0         1.3 MB  conda-forge
# ...

# %%
! git clone --branch aivsai https://github.com/huggingface/ml-agents
# Out:
# Cloning into 'ml-agents'...
# remote: Enumerating objects: 85464, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 85464 (delta 0), reused 4 (delta 0), pack-reused 85458
# Receiving objects: 100% (85464/85464), 2.48 GiB | 28.25 MiB/s, done.
# Resolving deltas: 100% (62411/62411), done.
# Updating files: 100% (2159/2159), done.

# %%
! cd ml-agents
! pip install -e ./ml-agents-envs
! pip install -e ./ml-agents
# Out:
# ERROR: ./ml-agents-envs is not a valid editable requirement. It should either be a path to a local project or a VCS URL (beginning with bzr+http, bzr+https, bzr+ssh, bzr+sftp, bzr+ftp, bzr+lp, bzr+file, git+http, git+https, git+ssh, git+git, git+file, hg+file, hg+http, hg+https, hg+ssh, hg+static-http, svn+ssh, svn+http, svn+https, svn+svn, svn+file).
# Obtaining file:///kaggle/working/ml-agents
# ERROR: file:///kaggle/working/ml-agents does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.

# %%
! pip install torch

# %%
# install git-lfs: https://git-lfs.com/
# add the environment training executable
# download one of them, unzip it and place it in a new folder inside ml-agents that you call training-envs-executables
# Linux (Ubuntu): Download https://drive.google.com/file/d/1KuqBKYiXiIcU4kNMqEzhgypuFP5_45CL/view?usp=sharing

# https://huggingface.co/deep-rl-course/unit7/hands-on?fw=pt#step-1-understand-the-environment

# https://huggingface.co/deep-rl-course/unit7/hands-on?fw=pt#the-reward-function

# https://huggingface.co/deep-rl-course/unit7/hands-on?fw=pt#the-observation-space

# https://huggingface.co/deep-rl-course/unit7/hands-on?fw=pt#the-action-space

# https://huggingface.co/deep-rl-course/unit7/hands-on?fw=pt#step-2-understand-mapoca

# https://huggingface.co/deep-rl-course/unit7/hands-on?fw=pt#step-3-define-the-config-file
config = """behaviors:
  SoccerTwos:
    trainer_type: poca
    hyperparameters:
      batch_size: 2048
      buffer_size: 20480
      learning_rate: 0.0003
      beta: 0.005
      epsilon: 0.2
      lambd: 0.95
      num_epoch: 3
      learning_rate_schedule: constant
    network_settings:
      normalize: false
      hidden_units: 512
      num_layers: 2
      vis_encode_type: simple
    reward_signals:
      extrinsic:
        gamma: 0.99
        strength: 1.0
    keep_checkpoints: 5
    max_steps: 5000000
    time_horizon: 1000
    summary_freq: 10000
    self_play:
      save_steps: 50000
      team_change: 200000
      swap_steps: 2000
      window: 10
      play_against_latest_model_ratio: 0.5
      initial_elo: 1200.0"""

with open("./config/poca/SoccerTwos.yaml") as infile:
    print(infile.read())

# https://huggingface.co/deep-rl-course/unit7/hands-on?fw=pt#step-4-start-the-training

# mlagents-learn ./config/poca/SoccerTwos.yaml --env=./training-envs-executables/SoccerTwos.exe --run-id="SoccerTwos" --no-graphics

# https://huggingface.co/deep-rl-course/unit7/hands-on?fw=pt#step-5-push-the-agent-to-the-hugging-face-hub

# huggingface-cli login

# mlagents-push-to-hf  --run-id="SoccerTwos" --local-dir="./results/SoccerTwos" --repo-id="ThomasSimonini/poca-SoccerTwos" --commit-message="First Push"`

# mlagents-push-to-hf  --run-id= # Add your run id  --local-dir= # Your local dir  --repo-id= # Your repo id --commit-message="First Push"

# https://huggingface.co/deep-rl-course/unit7/hands-on?fw=pt#step-6-verify-that-your-model-is-ready-for-ai-vs-ai-challenge

# https://huggingface.co/deep-rl-course/unit7/hands-on?fw=pt#step-7-visualize-some-match-in-our-demo
