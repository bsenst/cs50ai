# %%
# %%capture
# !apt install python-opengl -y
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay

# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# Install the specific setuptools version required to install the dependencies
# !pip install setuptools==65.5.0
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit6/requirements-unit6.txt
    
from huggingface_hub import HfApi, snapshot_download
from huggingface_hub.repocard import metadata_eval_result, metadata_save

from pathlib import Path
import datetime
import json
import imageio

import tempfile

import os

import pybullet_envs
import panda_gym
import gym

import os

from huggingface_sb3 import load_from_hub, package_to_hub

from stable_baselines3 import A2C
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.env_util import make_vec_env

from kaggle_secrets import UserSecretsClient
user_secrets = UserSecretsClient()
hf_token = user_secrets.get_secret("huggingface_rl_course")

from huggingface_hub import login
login(hf_token)

# %%
import gym

env_id = "PandaReachDense-v2"

# Create the env
env = gym.make(env_id)

# Get the state space and action space
s_size = env.observation_space.shape
a_size = env.action_space

print("_____OBSERVATION SPACE_____ \n")
print("The State Space is: ", s_size)
print("Sample observation", env.observation_space.sample()) # Get a random observation

print("\n _____ACTION SPACE_____ \n")
print("The Action Space is: ", a_size)
print("Action Space Sample", env.action_space.sample()) # Take a random action

# 1 - 2
env_id = "PandaReachDense-v2"
env = make_vec_env(env_id, n_envs=4)

# 3
env = VecNormalize(env, norm_obs=True, norm_reward=False, clip_obs=10.)

# 4
model = A2C(policy = "MultiInputPolicy",
            env = env,
            verbose=1)
# 5
# model.learn(1_000_000)
model.learn(500_000)

# 6
model_name = "a2c-PandaReachDense-v2"; 
model.save(model_name)
env.save("vec_normalize.pkl")

# 7
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize

# Load the saved statistics
eval_env = DummyVecEnv([lambda: gym.make("PandaReachDense-v2")])
eval_env = VecNormalize.load("vec_normalize.pkl", eval_env)

#  do not update them at test time
eval_env.training = False
# reward normalization is not needed at test time
eval_env.norm_reward = False

# Load the agent
model = A2C.load(model_name)

mean_reward, std_reward = evaluate_policy(model, eval_env)

print(f"Mean reward = {mean_reward:.2f} +/- {std_reward:.2f}")

# 8
package_to_hub(
    model=model,
    model_name=f"a2c-{env_id}",
    model_architecture="A2C",
    env_id=env_id,
    eval_env=eval_env,
    repo_id=f"bsenst/a2c-{env_id}", # TODO: Change the username
    commit_message=f"commit a2c-{env_id}",
)
# Out:
# pybullet build time: May 20 2022 19:43:01
# _____OBSERVATION SPACE_____
#
# The State Space is:  None
# Sample observation OrderedDict([('achieved_goal', array([ 3.7190974,  6.4633203, -2.2173216], dtype=float32)), ('desired_goal', array([-3.1154325 ,  4.0476785 , -0.08282012], dtype=float32)), ('observation', array([-9.543845 ,  5.731943 , -9.858893 , -5.741115 ,  2.889457 ,
#        -1.3212855], dtype=float32))])
#
#  _____ACTION SPACE_____
#
# The Action Space is:  Box([-1. -1. -1.], [1. 1. 1.], (3,), float32)
# Action Space Sample [-0.32593247 -0.01460739 -0.8549918 ]
# Using cpu device
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -13.6    |
# | time/                 |          |
# |    fps                | 346      |
# |    iterations         | 100      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 2000     |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | 0.477    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 99       |
# |    policy_loss        | -3.29    |
# |    std                | 1.01     |
# |    value_loss         | 1.63     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -16.4    |
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 200      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | 0.987    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -4.6     |
# |    std                | 1.01     |
# |    value_loss         | 1.48     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -16.6    |
# | time/                 |          |
# |    fps                | 336      |
# |    iterations         | 300      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 6000     |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.922    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -1.39    |
# |    std                | 1.01     |
# |    value_loss         | 0.238    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -15.4    |
# | time/                 |          |
# |    fps                | 334      |
# |    iterations         | 400      |
# |    time_elapsed       | 23       |
# |    total_timesteps    | 8000     |
# | train/                |          |
# |    entropy_loss       | -4.31    |
# |    explained_variance | 0.204    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 399      |
# |    policy_loss        | -5.28    |
# |    std                | 1.02     |
# |    value_loss         | 2.91     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -13.7    |
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 500      |
# |    time_elapsed       | 29       |
# |    total_timesteps    | 10000    |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.859    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 499      |
# |    policy_loss        | -0.648   |
# |    std                | 1.02     |
# |    value_loss         | 0.0706   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -12.7    |
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 600      |
# |    time_elapsed       | 35       |
# |    total_timesteps    | 12000    |
# | train/                |          |
# |    entropy_loss       | -4.34    |
# |    explained_variance | 0.956    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -3.01    |
# |    std                | 1.03     |
# |    value_loss         | 1.17     |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -11      |
# | time/                 |          |
# |    fps                | 337      |
# |    iterations         | 700      |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.953    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | -0.0132  |
# |    std                | 1.02     |
# |    value_loss         | 0.0867   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -11      |
# | time/                 |          |
# |    fps                | 337      |
# |    iterations         | 800      |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 16000    |
# | train/                |          |
# |    entropy_loss       | -4.32    |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -1.66    |
# |    std                | 1.02     |
# |    value_loss         | 0.362    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -10.8    |
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 900      |
# |    time_elapsed       | 53       |
# |    total_timesteps    | 18000    |
# | train/                |          |
# |    entropy_loss       | -4.31    |
# |    explained_variance | 0.871    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -0.576   |
# |    std                | 1.02     |
# |    value_loss         | 0.241    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -10.9    |
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 1000     |
# |    time_elapsed       | 59       |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -4.32    |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | 0.0872   |
# |    std                | 1.02     |
# |    value_loss         | 0.0948   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -10.4    |
# | time/                 |          |
# |    fps                | 333      |
# |    iterations         | 1100     |
# |    time_elapsed       | 65       |
# |    total_timesteps    | 22000    |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.971    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | -1.36    |
# |    std                | 1.03     |
# |    value_loss         | 0.267    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -9.69    |
# | time/                 |          |
# |    fps                | 332      |
# |    iterations         | 1200     |
# |    time_elapsed       | 72       |
# |    total_timesteps    | 24000    |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1199     |
# |    policy_loss        | -0.324   |
# |    std                | 1.02     |
# |    value_loss         | 0.0319   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -9.09    |
# | time/                 |          |
# |    fps                | 332      |
# |    iterations         | 1300     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -4.35    |
# |    explained_variance | 0.996    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1299     |
# |    policy_loss        | 0.492    |
# |    std                | 1.03     |
# |    value_loss         | 0.108    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -8.78    |
# | time/                 |          |
# |    fps                | 332      |
# |    iterations         | 1400     |
# |    time_elapsed       | 84       |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -4.35    |
# |    explained_variance | 0.93     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1399     |
# |    policy_loss        | -1.79    |
# |    std                | 1.03     |
# |    value_loss         | 0.438    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -8.66    |
# | time/                 |          |
# |    fps                | 332      |
# |    iterations         | 1500     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -4.33    |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | -1.71    |
# |    std                | 1.02     |
# |    value_loss         | 0.281    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -8.33    |
# | time/                 |          |
# |    fps                | 333      |
# |    iterations         | 1600     |
# |    time_elapsed       | 95       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -4.32    |
# |    explained_variance | 0.991    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1599     |
# |    policy_loss        | -0.993   |
# |    std                | 1.02     |
# |    value_loss         | 0.281    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -7.87    |
# | time/                 |          |
# |    fps                | 333      |
# |    iterations         | 1700     |
# |    time_elapsed       | 101      |
# |    total_timesteps    | 34000    |
# | train/                |          |
# |    entropy_loss       | -4.32    |
# |    explained_variance | 0.987    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -0.141   |
# |    std                | 1.02     |
# |    value_loss         | 0.253    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -7.63    |
# | time/                 |          |
# |    fps                | 334      |
# |    iterations         | 1800     |
# |    time_elapsed       | 107      |
# |    total_timesteps    | 36000    |
# | train/                |          |
# |    entropy_loss       | -4.31    |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -0.24    |
# |    std                | 1.02     |
# |    value_loss         | 0.0796   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -7.6     |
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 1900     |
# |    time_elapsed       | 113      |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1899     |
# |    policy_loss        | -1.35    |
# |    std                | 1.01     |
# |    value_loss         | 0.146    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -7.42    |
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 2000     |
# |    time_elapsed       | 119      |
# |    total_timesteps    | 40000    |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1999     |
# |    policy_loss        | 1.09     |
# |    std                | 1.02     |
# |    value_loss         | 0.237    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -7.28    |
# | time/                 |          |
# |    fps                | 335      |
# |    iterations         | 2100     |
# |    time_elapsed       | 125      |
# |    total_timesteps    | 42000    |
# | train/                |          |
# |    entropy_loss       | -4.3     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2099     |
# |    policy_loss        | -1.68    |
# |    std                | 1.01     |
# |    value_loss         | 0.213    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -7.1     |
# | time/                 |          |
# |    fps                | 336      |
# |    iterations         | 2200     |
# |    time_elapsed       | 130      |
# |    total_timesteps    | 44000    |
# | train/                |          |
# |    entropy_loss       | -4.29    |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2199     |
# |    policy_loss        | -0.187   |
# |    std                | 1.01     |
# |    value_loss         | 0.0182   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -6.91    |
# | time/                 |          |
# |    fps                | 337      |
# |    iterations         | 2300     |
# |    time_elapsed       | 136      |
# |    total_timesteps    | 46000    |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.958    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2299     |
# |    policy_loss        | 0.123    |
# |    std                | 1.01     |
# |    value_loss         | 0.0803   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -6.31    |
# | time/                 |          |
# |    fps                | 338      |
# |    iterations         | 2400     |
# |    time_elapsed       | 141      |
# |    total_timesteps    | 48000    |
# | train/                |          |
# |    entropy_loss       | -4.28    |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2399     |
# |    policy_loss        | 0.0703   |
# |    std                | 1.01     |
# |    value_loss         | 0.00583  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -5.57    |
# | time/                 |          |
# |    fps                | 339      |
# |    iterations         | 2500     |
# |    time_elapsed       | 147      |
# |    total_timesteps    | 50000    |
# | train/                |          |
# |    entropy_loss       | -4.27    |
# |    explained_variance | 0.986    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2499     |
# |    policy_loss        | -0.199   |
# |    std                | 1        |
# |    value_loss         | 0.0223   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.92    |
# | time/                 |          |
# |    fps                | 340      |
# |    iterations         | 2600     |
# |    time_elapsed       | 152      |
# |    total_timesteps    | 52000    |
# | train/                |          |
# |    entropy_loss       | -4.26    |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2599     |
# |    policy_loss        | -0.288   |
# |    std                | 1        |
# |    value_loss         | 0.0143   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.5     |
# | time/                 |          |
# |    fps                | 342      |
# |    iterations         | 2700     |
# |    time_elapsed       | 157      |
# |    total_timesteps    | 54000    |
# | train/                |          |
# |    entropy_loss       | -4.23    |
# |    explained_variance | 0.647    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | 0.207    |
# |    std                | 0.993    |
# |    value_loss         | 0.0268   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -4.02    |
# | time/                 |          |
# |    fps                | 343      |
# |    iterations         | 2800     |
# |    time_elapsed       | 163      |
# |    total_timesteps    | 56000    |
# | train/                |          |
# |    entropy_loss       | -4.21    |
# |    explained_variance | 0.986    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | -0.0836  |
# |    std                | 0.984    |
# |    value_loss         | 0.014    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.58    |
# | time/                 |          |
# |    fps                | 345      |
# |    iterations         | 2900     |
# |    time_elapsed       | 168      |
# |    total_timesteps    | 58000    |
# | train/                |          |
# |    entropy_loss       | -4.18    |
# |    explained_variance | 0.865    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2899     |
# |    policy_loss        | 0.0253   |
# |    std                | 0.976    |
# |    value_loss         | 0.013    |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.38    |
# | time/                 |          |
# |    fps                | 346      |
# |    iterations         | 3000     |
# |    time_elapsed       | 173      |
# |    total_timesteps    | 60000    |
# | train/                |          |
# |    entropy_loss       | -4.18    |
# |    explained_variance | 0.884    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2999     |
# |    policy_loss        | 0.043    |
# |    std                | 0.975    |
# |    value_loss         | 0.00902  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.33    |
# | time/                 |          |
# |    fps                | 347      |
# |    iterations         | 3100     |
# |    time_elapsed       | 178      |
# |    total_timesteps    | 62000    |
# | train/                |          |
# |    entropy_loss       | -4.17    |
# |    explained_variance | 0.545    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3099     |
# |    policy_loss        | -0.0515  |
# |    std                | 0.972    |
# |    value_loss         | 0.0086   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -3.21    |
# | time/                 |          |
# |    fps                | 348      |
# |    iterations         | 3200     |
# |    time_elapsed       | 183      |
# |    total_timesteps    | 64000    |
# | train/                |          |
# |    entropy_loss       | -4.13    |
# |    explained_variance | 0.657    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3199     |
# |    policy_loss        | 0.0278   |
# |    std                | 0.96     |
# |    value_loss         | 0.00856  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.93    |
# | time/                 |          |
# |    fps                | 349      |
# |    iterations         | 3300     |
# |    time_elapsed       | 188      |
# |    total_timesteps    | 66000    |
# | train/                |          |
# |    entropy_loss       | -4.12    |
# |    explained_variance | 0.818    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | -0.00767 |
# |    std                | 0.954    |
# |    value_loss         | 0.0179   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.78    |
# | time/                 |          |
# |    fps                | 350      |
# |    iterations         | 3400     |
# |    time_elapsed       | 194      |
# |    total_timesteps    | 68000    |
# | train/                |          |
# |    entropy_loss       | -4.11    |
# |    explained_variance | 0.954    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3399     |
# |    policy_loss        | -0.0763  |
# |    std                | 0.951    |
# |    value_loss         | 0.0146   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.67    |
# | time/                 |          |
# |    fps                | 351      |
# |    iterations         | 3500     |
# |    time_elapsed       | 199      |
# |    total_timesteps    | 70000    |
# | train/                |          |
# |    entropy_loss       | -4.07    |
# |    explained_variance | 0.979    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 0.0837   |
# |    std                | 0.939    |
# |    value_loss         | 0.00123  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.58    |
# | time/                 |          |
# |    fps                | 351      |
# |    iterations         | 3600     |
# |    time_elapsed       | 204      |
# |    total_timesteps    | 72000    |
# | train/                |          |
# |    entropy_loss       | -4.03    |
# |    explained_variance | 0.971    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3599     |
# |    policy_loss        | -0.0052  |
# |    std                | 0.929    |
# |    value_loss         | 0.00478  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.57    |
# | time/                 |          |
# |    fps                | 352      |
# |    iterations         | 3700     |
# |    time_elapsed       | 209      |
# |    total_timesteps    | 74000    |
# | train/                |          |
# |    entropy_loss       | -4       |
# |    explained_variance | 0.861    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | 0.0445   |
# |    std                | 0.918    |
# |    value_loss         | 0.00541  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.49    |
# | time/                 |          |
# |    fps                | 353      |
# |    iterations         | 3800     |
# |    time_elapsed       | 215      |
# |    total_timesteps    | 76000    |
# | train/                |          |
# |    entropy_loss       | -3.96    |
# |    explained_variance | 0.906    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3799     |
# |    policy_loss        | -0.084   |
# |    std                | 0.908    |
# |    value_loss         | 0.00452  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.32    |
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 3900     |
# |    time_elapsed       | 220      |
# |    total_timesteps    | 78000    |
# | train/                |          |
# |    entropy_loss       | -3.95    |
# |    explained_variance | 0.959    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3899     |
# |    policy_loss        | 0.129    |
# |    std                | 0.904    |
# |    value_loss         | 0.00502  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.2     |
# | time/                 |          |
# |    fps                | 354      |
# |    iterations         | 4000     |
# |    time_elapsed       | 225      |
# |    total_timesteps    | 80000    |
# | train/                |          |
# |    entropy_loss       | -3.92    |
# |    explained_variance | 0.842    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -0.235   |
# |    std                | 0.896    |
# |    value_loss         | 0.0137   |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.13    |
# | time/                 |          |
# |    fps                | 355      |
# |    iterations         | 4100     |
# |    time_elapsed       | 230      |
# |    total_timesteps    | 82000    |
# | train/                |          |
# |    entropy_loss       | -3.89    |
# |    explained_variance | 0.895    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | 0.113    |
# |    std                | 0.885    |
# |    value_loss         | 0.00225  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -2.04    |
# | time/                 |          |
# |    fps                | 356      |
# |    iterations         | 4200     |
# |    time_elapsed       | 235      |
# |    total_timesteps    | 84000    |
# | train/                |          |
# |    entropy_loss       | -3.87    |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4199     |
# |    policy_loss        | -0.0519  |
# |    std                | 0.88     |
# |    value_loss         | 0.00108  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.94    |
# | time/                 |          |
# |    fps                | 357      |
# |    iterations         | 4300     |
# |    time_elapsed       | 240      |
# |    total_timesteps    | 86000    |
# | train/                |          |
# |    entropy_loss       | -3.83    |
# |    explained_variance | 0.984    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -0.0595  |
# |    std                | 0.868    |
# |    value_loss         | 0.00218  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.91    |
# | time/                 |          |
# |    fps                | 357      |
# |    iterations         | 4400     |
# |    time_elapsed       | 245      |
# |    total_timesteps    | 88000    |
# | train/                |          |
# |    entropy_loss       | -3.78    |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4399     |
# |    policy_loss        | 0.134    |
# |    std                | 0.856    |
# |    value_loss         | 0.00463  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.92    |
# | time/                 |          |
# |    fps                | 358      |
# |    iterations         | 4500     |
# |    time_elapsed       | 251      |
# |    total_timesteps    | 90000    |
# | train/                |          |
# |    entropy_loss       | -3.75    |
# |    explained_variance | 0.992    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4499     |
# |    policy_loss        | -0.00413 |
# |    std                | 0.846    |
# |    value_loss         | 0.00137  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.88    |
# | time/                 |          |
# |    fps                | 359      |
# |    iterations         | 4600     |
# |    time_elapsed       | 256      |
# |    total_timesteps    | 92000    |
# | train/                |          |
# |    entropy_loss       | -3.71    |
# |    explained_variance | 0.894    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 0.0163   |
# |    std                | 0.835    |
# |    value_loss         | 0.00385  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.8     |
# | time/                 |          |
# |    fps                | 359      |
# |    iterations         | 4700     |
# |    time_elapsed       | 261      |
# |    total_timesteps    | 94000    |
# | train/                |          |
# |    entropy_loss       | -3.66    |
# |    explained_variance | 0.724    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | 0.0452   |
# |    std                | 0.822    |
# |    value_loss         | 0.00172  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.8     |
# | time/                 |          |
# |    fps                | 360      |
# |    iterations         | 4800     |
# |    time_elapsed       | 266      |
# |    total_timesteps    | 96000    |
# | train/                |          |
# |    entropy_loss       | -3.62    |
# |    explained_variance | 0.54     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4799     |
# |    policy_loss        | 0.0197   |
# |    std                | 0.812    |
# |    value_loss         | 0.00213  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.78    |
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 4900     |
# |    time_elapsed       | 271      |
# |    total_timesteps    | 98000    |
# | train/                |          |
# |    entropy_loss       | -3.58    |
# |    explained_variance | 0.984    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4899     |
# |    policy_loss        | 0.136    |
# |    std                | 0.802    |
# |    value_loss         | 0.00238  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.76    |
# | time/                 |          |
# |    fps                | 361      |
# |    iterations         | 5000     |
# |    time_elapsed       | 276      |
# |    total_timesteps    | 100000   |
# | train/                |          |
# |    entropy_loss       | -3.54    |
# |    explained_variance | 0.997    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4999     |
# |    policy_loss        | 0.0649   |
# |    std                | 0.79     |
# |    value_loss         | 0.000978 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.75    |
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 5100     |
# |    time_elapsed       | 281      |
# |    total_timesteps    | 102000   |
# | train/                |          |
# |    entropy_loss       | -3.51    |
# |    explained_variance | 0.949    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 0.0643   |
# |    std                | 0.784    |
# |    value_loss         | 0.00116  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.75    |
# | time/                 |          |
# |    fps                | 362      |
# |    iterations         | 5200     |
# |    time_elapsed       | 286      |
# |    total_timesteps    | 104000   |
# | train/                |          |
# |    entropy_loss       | -3.47    |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | 0.0188   |
# |    std                | 0.771    |
# |    value_loss         | 0.00053  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.73    |
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 5300     |
# |    time_elapsed       | 292      |
# |    total_timesteps    | 106000   |
# | train/                |          |
# |    entropy_loss       | -3.42    |
# |    explained_variance | 0.988    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5299     |
# |    policy_loss        | -0.0293  |
# |    std                | 0.761    |
# |    value_loss         | 0.00148  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.72    |
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 5400     |
# |    time_elapsed       | 297      |
# |    total_timesteps    | 108000   |
# | train/                |          |
# |    entropy_loss       | -3.38    |
# |    explained_variance | 0.967    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5399     |
# |    policy_loss        | -0.0793  |
# |    std                | 0.75     |
# |    value_loss         | 0.00233  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.7     |
# | time/                 |          |
# |    fps                | 363      |
# |    iterations         | 5500     |
# |    time_elapsed       | 302      |
# |    total_timesteps    | 110000   |
# | train/                |          |
# |    entropy_loss       | -3.34    |
# |    explained_variance | -0.915   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | -0.00361 |
# |    std                | 0.739    |
# |    value_loss         | 0.00276  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.71    |
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 5600     |
# |    time_elapsed       | 307      |
# |    total_timesteps    | 112000   |
# | train/                |          |
# |    entropy_loss       | -3.31    |
# |    explained_variance | 0.952    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 0.00402  |
# |    std                | 0.731    |
# |    value_loss         | 0.00105  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.68    |
# | time/                 |          |
# |    fps                | 364      |
# |    iterations         | 5700     |
# |    time_elapsed       | 312      |
# |    total_timesteps    | 114000   |
# | train/                |          |
# |    entropy_loss       | -3.26    |
# |    explained_variance | 0.974    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 0.0509   |
# |    std                | 0.721    |
# |    value_loss         | 0.00145  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.63    |
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 5800     |
# |    time_elapsed       | 317      |
# |    total_timesteps    | 116000   |
# | train/                |          |
# |    entropy_loss       | -3.21    |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -0.104   |
# |    std                | 0.708    |
# |    value_loss         | 0.00133  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.65    |
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 5900     |
# |    time_elapsed       | 322      |
# |    total_timesteps    | 118000   |
# | train/                |          |
# |    entropy_loss       | -3.18    |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5899     |
# |    policy_loss        | -0.145   |
# |    std                | 0.701    |
# |    value_loss         | 0.00271  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.64    |
# | time/                 |          |
# |    fps                | 365      |
# |    iterations         | 6000     |
# |    time_elapsed       | 328      |
# |    total_timesteps    | 120000   |
# | train/                |          |
# |    entropy_loss       | -3.12    |
# |    explained_variance | 0.983    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -0.0858  |
# |    std                | 0.686    |
# |    value_loss         | 0.00242  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.63    |
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 6100     |
# |    time_elapsed       | 333      |
# |    total_timesteps    | 122000   |
# | train/                |          |
# |    entropy_loss       | -3.11    |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6099     |
# |    policy_loss        | -0.015   |
# |    std                | 0.684    |
# |    value_loss         | 0.000245 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.64    |
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 6200     |
# |    time_elapsed       | 338      |
# |    total_timesteps    | 124000   |
# | train/                |          |
# |    entropy_loss       | -3.07    |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6199     |
# |    policy_loss        | 0.000666 |
# |    std                | 0.675    |
# |    value_loss         | 0.000883 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.66    |
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 6300     |
# |    time_elapsed       | 343      |
# |    total_timesteps    | 126000   |
# | train/                |          |
# |    entropy_loss       | -3.02    |
# |    explained_variance | 0.976    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6299     |
# |    policy_loss        | 0.0154   |
# |    std                | 0.665    |
# |    value_loss         | 0.00161  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.67    |
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 6400     |
# |    time_elapsed       | 349      |
# |    total_timesteps    | 128000   |
# | train/                |          |
# |    entropy_loss       | -2.98    |
# |    explained_variance | 0.993    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -0.0563  |
# |    std                | 0.657    |
# |    value_loss         | 0.000795 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.68    |
# | time/                 |          |
# |    fps                | 366      |
# |    iterations         | 6500     |
# |    time_elapsed       | 354      |
# |    total_timesteps    | 130000   |
# | train/                |          |
# |    entropy_loss       | -2.96    |
# |    explained_variance | 0.94     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -0.0295  |
# |    std                | 0.652    |
# |    value_loss         | 0.000767 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.67    |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 6600     |
# |    time_elapsed       | 359      |
# |    total_timesteps    | 132000   |
# | train/                |          |
# |    entropy_loss       | -2.94    |
# |    explained_variance | 0.985    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -0.0514  |
# |    std                | 0.647    |
# |    value_loss         | 0.000728 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.64    |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 6700     |
# |    time_elapsed       | 364      |
# |    total_timesteps    | 134000   |
# | train/                |          |
# |    entropy_loss       | -2.91    |
# |    explained_variance | 0.972    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | 0.000721 |
# |    std                | 0.641    |
# |    value_loss         | 0.000914 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.63    |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 6800     |
# |    time_elapsed       | 370      |
# |    total_timesteps    | 136000   |
# | train/                |          |
# |    entropy_loss       | -2.9     |
# |    explained_variance | 0.988    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6799     |
# |    policy_loss        | 0.0786   |
# |    std                | 0.639    |
# |    value_loss         | 0.000868 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.63    |
# | time/                 |          |
# |    fps                | 367      |
# |    iterations         | 6900     |
# |    time_elapsed       | 375      |
# |    total_timesteps    | 138000   |
# | train/                |          |
# |    entropy_loss       | -2.86    |
# |    explained_variance | 0.981    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -0.0398  |
# |    std                | 0.63     |
# |    value_loss         | 0.00119  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.63    |
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 7000     |
# |    time_elapsed       | 380      |
# |    total_timesteps    | 140000   |
# | train/                |          |
# |    entropy_loss       | -2.85    |
# |    explained_variance | 0.987    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 0.03     |
# |    std                | 0.628    |
# |    value_loss         | 0.000563 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -1.63    |
# | time/                 |          |
# |    fps                | 368      |
# |    iterations         | 7100     |
# |    time_elapsed       | 385      |
# |    total_timesteps    | 142000   |
# | train/                |          |
# |    entropy_loss       | -2.79    |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7099     |
# |    policy_loss        | -0.0419  |
# |    std                | 0.616    |
# |    value_loss         | 0.00177  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# ...
# | time/                 |          |
# |    fps                | 345      |
# |    iterations         | 24000    |
# |    time_elapsed       | 1388     |
# |    total_timesteps    | 480000   |
# | train/                |          |
# |    entropy_loss       | 4.73     |
# |    explained_variance | 0.994    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 23999    |
# |    policy_loss        | -0.00405 |
# |    std                | 0.0508   |
# |    value_loss         | 7.87e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -0.674   |
# | time/                 |          |
# |    fps                | 345      |
# |    iterations         | 24100    |
# |    time_elapsed       | 1395     |
# |    total_timesteps    | 482000   |
# | train/                |          |
# |    entropy_loss       | 4.76     |
# |    explained_variance | 0.989    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24099    |
# |    policy_loss        | -0.00506 |
# |    std                | 0.0503   |
# |    value_loss         | 2.54e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -0.632   |
# | time/                 |          |
# |    fps                | 345      |
# |    iterations         | 24200    |
# |    time_elapsed       | 1401     |
# |    total_timesteps    | 484000   |
# | train/                |          |
# |    entropy_loss       | 4.79     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24199    |
# |    policy_loss        | -0.0206  |
# |    std                | 0.0496   |
# |    value_loss         | 2.8e-05  |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -0.546   |
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 24300    |
# |    time_elapsed       | 1408     |
# |    total_timesteps    | 486000   |
# | train/                |          |
# |    entropy_loss       | 4.83     |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24299    |
# |    policy_loss        | -0.00203 |
# |    std                | 0.049    |
# |    value_loss         | 1.11e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -0.651   |
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 24400    |
# |    time_elapsed       | 1415     |
# |    total_timesteps    | 488000   |
# | train/                |          |
# |    entropy_loss       | 4.84     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24399    |
# |    policy_loss        | 0.0637   |
# |    std                | 0.0488   |
# |    value_loss         | 0.000676 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -0.787   |
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 24500    |
# |    time_elapsed       | 1422     |
# |    total_timesteps    | 490000   |
# | train/                |          |
# |    entropy_loss       | 4.88     |
# |    explained_variance | 0.999    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24499    |
# |    policy_loss        | 0.0102   |
# |    std                | 0.0483   |
# |    value_loss         | 5.07e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -0.96    |
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 24600    |
# |    time_elapsed       | 1428     |
# |    total_timesteps    | 492000   |
# | train/                |          |
# |    entropy_loss       | 4.89     |
# |    explained_variance | 0.99     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24599    |
# |    policy_loss        | 0.0272   |
# |    std                | 0.048    |
# |    value_loss         | 0.000175 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -0.887   |
# | time/                 |          |
# |    fps                | 344      |
# |    iterations         | 24700    |
# |    time_elapsed       | 1435     |
# |    total_timesteps    | 494000   |
# | train/                |          |
# |    entropy_loss       | 4.91     |
# |    explained_variance | 0.995    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24699    |
# |    policy_loss        | -0.00809 |
# |    std                | 0.0477   |
# |    value_loss         | 4.98e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -0.678   |
# | time/                 |          |
# |    fps                | 343      |
# |    iterations         | 24800    |
# |    time_elapsed       | 1442     |
# |    total_timesteps    | 496000   |
# | train/                |          |
# |    entropy_loss       | 4.96     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24799    |
# |    policy_loss        | -0.0263  |
# |    std                | 0.0469   |
# |    value_loss         | 6.47e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -0.538   |
# | time/                 |          |
# |    fps                | 343      |
# |    iterations         | 24900    |
# |    time_elapsed       | 1449     |
# |    total_timesteps    | 498000   |
# | train/                |          |
# |    entropy_loss       | 5.02     |
# |    explained_variance | 0.998    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24899    |
# |    policy_loss        | -0.00879 |
# |    std                | 0.0459   |
# |    value_loss         | 5.64e-05 |
# ------------------------------------
# ------------------------------------
# | rollout/              |          |
# |    ep_len_mean        | 50       |
# |    ep_rew_mean        | -0.549   |
# | time/                 |          |
# |    fps                | 343      |
# |    iterations         | 25000    |
# |    time_elapsed       | 1455     |
# |    total_timesteps    | 500000   |
# | train/                |          |
# |    entropy_loss       | 5.07     |
# |    explained_variance | 0.98     |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 24999    |
# |    policy_loss        | 0.0151   |
# |    std                | 0.0452   |
# |    value_loss         | 0.000107 |
# ------------------------------------
# /opt/conda/lib/python3.7/site-packages/stable_baselines3/common/evaluation.py:71: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   UserWarning,
# Mean reward = -0.64 +/- 0.14
# [i] This function will save, evaluate, generate a video of your agent,
# create a model card and push everything to the hub. It might take up to 1min.
# This is a work in progress: if you encounter a bug, please open an issue.
# /opt/conda/lib/python3.7/site-packages/panda_gym/pybullet.py:102: UserWarning: The use of the render method is not recommended when the environment has not been created with render=True. The rendering will probably be weird. Prefer making the environment with option `render=True`. For example: `env = gym.make('PandaReach-v2', render=True)`.
#   UserWarning,
# ffmpeg: /opt/conda/lib/libncursesw.so.6: no version information available (required by /lib/x86_64-linux-gnu/libcaca.so.0)
# ffmpeg: /opt/conda/lib/libncursesw.so.6: no version information available (required by /lib/x86_64-linux-gnu/libcaca.so.0)
# /opt/conda/lib/python3.7/site-packages/panda_gym/pybullet.py:102: UserWarning: The use of the render method is not recommended when the environment has not been created with render=True. The rendering will probably be weird. Prefer making the environment with option `render=True`. For example: `env = gym.make('PandaReach-v2', render=True)`.
#   UserWarning,
# Saving video to /tmp/tmp_5ncjsns/-step-0-to-step-1000.mp4
# ffmpeg: /opt/conda/lib/libncursesw.so.6: no version information available (required by /lib/x86_64-linux-gnu/libcaca.so.0)
# ffmpeg: /opt/conda/lib/libncursesw.so.6: no version information available (required by /lib/x86_64-linux-gnu/libcaca.so.0)
# ffmpeg version 4.2.7-0ubuntu0.1 Copyright (c) 2000-2022 the FFmpeg developers
#   built with gcc 9 (Ubuntu 9.4.0-1ubuntu1~20.04.1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-avresample --disable-filter=resample --enable-avisynth --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librsvg --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwavpack --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-nvenc --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 31.100 / 56. 31.100
#   libavcodec     58. 54.100 / 58. 54.100
#   libavformat    58. 29.100 / 58. 29.100
#   libavdevice    58.  8.100 / 58.  8.100
#   libavfilter     7. 57.100 /  7. 57.100
#   libavresample   4.  0.  0 /  4.  0.  0
#   libswscale      5.  5.100 /  5.  5.100
#   libswresample   3.  5.100 /  3.  5.100
#   libpostproc    55.  5.100 / 55.  5.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from '/tmp/tmp_5ncjsns/-step-0-to-step-1000.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#   Duration: 00:00:33.37, start: 0.000000, bitrate: 82 kb/s
#     Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 720x480, 79 kb/s, 30 fps, 30 tbr, 15360 tbn, 60 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5c52ef21a3c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5c52ef21a3c0] profile High, level 3.0
# [libx264 @ 0x5c52ef21a3c0] 264 - core 155 r2917 0a84d98 - H.264/MPEG-4 AVC codec - Copyleft 2003-2018 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=6 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=25 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to '/tmp/tmptf6mks2r/replay.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.29.100
#     Stream #0:0(und): Video: h264 (libx264) (avc1 / 0x31637661), yuv420p, 720x480, q=-1--1, 30 fps, 15360 tbn, 30 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       encoder         : Lavc58.54.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: -1
# frame= 1001 fps=432 q=-1.0 Lsize=     333kB time=00:00:33.26 bitrate=  82.1kbits/s speed=14.4x
# video:321kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.892977%
# [libx264 @ 0x5c52ef21a3c0] frame I:5     Avg QP:19.07  size:  6752
# [libx264 @ 0x5c52ef21a3c0] frame P:259   Avg QP:17.97  size:   599
# [libx264 @ 0x5c52ef21a3c0] frame B:737   Avg QP:19.75  size:   189
# [libx264 @ 0x5c52ef21a3c0] consecutive B-frames:  1.3%  1.0%  1.8% 95.9%
# [libx264 @ 0x5c52ef21a3c0] mb I  I16..4:  2.8% 81.4% 15.8%
# [libx264 @ 0x5c52ef21a3c0] mb P  I16..4:  0.1%  0.2%  0.2%  P16..4:  1.1%  0.7%  0.5%  0.0%  0.0%    skip:97.2%
# [libx264 @ 0x5c52ef21a3c0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  1.7%  0.5%  0.2%  direct: 0.1%  skip:97.5%  L0:47.5% L1:49.8% BI: 2.6%
# [libx264 @ 0x5c52ef21a3c0] 8x8 transform intra:70.6% inter:6.9%
# [libx264 @ 0x5c52ef21a3c0] coded y,uvDC,uvAC intra: 13.8% 1.9% 0.9% inter: 0.4% 0.0% 0.0%
# [libx264 @ 0x5c52ef21a3c0] i16 v,h,dc,p: 41% 20% 38%  1%
# [libx264 @ 0x5c52ef21a3c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 60% 12% 27%  0%  0%  0%  0%  0%  0%
# [libx264 @ 0x5c52ef21a3c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33% 18% 23%  3%  6%  4%  7%  2%  5%
# [libx264 @ 0x5c52ef21a3c0] i8c dc,h,v,p: 96%  2%  2%  0%
# [libx264 @ 0x5c52ef21a3c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5c52ef21a3c0] ref P L0: 64.6%  6.2% 19.5%  9.6%
# [libx264 @ 0x5c52ef21a3c0] ref B L0: 64.7% 32.1%  3.2%
# [libx264 @ 0x5c52ef21a3c0] ref B L1: 89.2% 10.8%
# [libx264 @ 0x5c52ef21a3c0] kb/s:78.61
# Exception ignored in: <function VecVideoRecorder.__del__ at 0x74d6cd9117a0>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.7/site-packages/stable_baselines3/common/vec_env/vec_video_recorder.py", line 112, in __del__
#     self.close()
#   File "/opt/conda/lib/python3.7/site-packages/stable_baselines3/common/vec_env/vec_video_recorder.py", line 108, in close
#     VecEnvWrapper.close(self)
#   File "/opt/conda/lib/python3.7/site-packages/stable_baselines3/common/vec_env/base_vec_env.py", line 279, in close
#     return self.venv.close()
#   File "/opt/conda/lib/python3.7/site-packages/stable_baselines3/common/vec_env/base_vec_env.py", line 279, in close
#     return self.venv.close()
#   File "/opt/conda/lib/python3.7/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py", line 80, in close
#     env.close()
#   File "/opt/conda/lib/python3.7/site-packages/gym/core.py", line 298, in close
#     return self.env.close()
#   File "/opt/conda/lib/python3.7/site-packages/panda_gym/envs/core.py", line 279, in close
#     self.sim.close()
#   File "/opt/conda/lib/python3.7/site-packages/panda_gym/pybullet.py", line 59, in close
#     self.physics_client.disconnect()
# pybullet.error: Not connected to physics server.
# [i] Pushing repo bsenst/a2c-PandaReachDense-v2 to the Hugging Face
# Hub
# policy.pth:   0%|          | 0.00/45.9k [00:00<?, ?B/s]
# a2c-PandaReachDense-v2.zip:   0%|          | 0.00/108k [00:00<?, ?B/s]
# policy.optimizer.pth:   0%|          | 0.00/44.6k [00:00<?, ?B/s]
# vec_normalize.pkl:   0%|          | 0.00/2.75k [00:00<?, ?B/s]
# Upload 4 LFS files:   0%|          | 0/4 [00:00<?, ?it/s]
# [i] Your model is pushed to the Hub. You can view your model here:
# https://huggingface.co/bsenst/a2c-PandaReachDense-v2/tree/main/
# 'https://huggingface.co/bsenst/a2c-PandaReachDense-v2/tree/main/'

# %%
# PandaPickAndPlace-v1
# HalfCheetahBulletEnv-v0
